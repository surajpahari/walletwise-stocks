# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
file_path = "../scripts/data/csvs/PFL.csv"
df = pd.read_csv(file_path)

# Resetting the index and updating the DataFrame in place
df = df.reset_index(drop=True)

# Dropping the specified columns
df = df.drop(columns=['published_date', 'status','traded_quantity','per_change'])

df.head()
# Out:
#    open  high   low  close  traded_amount
# 0  98.0  97.0  96.0   96.0         1930.0
# 1  96.0  95.0  92.0   92.0        12316.0
# 2  92.0  91.0  91.0   91.0         5460.0
# 3  91.0  92.0  92.0   92.0         4600.0
# 4  92.0  93.0  93.0   93.0        18786.0

# %%
plt.plot(df.close)

# %%
ma100 = df.close.rolling(100).mean()
ma100
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 2098    496.363
# 2099    499.443
# 2100    502.383
# 2101    505.123
# 2102    507.703
# Name: close, Length: 2103, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.close)
plt.plot(ma100)

# %%
ma200 = df.close.rolling(200).mean()
ma200
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 2098    423.6885
# 2099    425.2785
# 2100    426.7765
# 2101    428.1715
# 2102    429.4465
# Name: close, Length: 2103, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.close)
plt.plot(ma100)
plt.plot(ma200)

# %%
plt.figure(figsize=(12,6))
plt.plot(df.close)
plt.plot(ma100)
plt.plot(ma200)

# %%
data_training=pd.DataFrame(df['close'][0:int(len(df)*0.70)])
data_testing=pd.DataFrame(df['close'][int(len(df)*0.70):int(len(df))])
print(data_training)
# Out:
#       close
# 0      96.0
# 1      92.0
# 2      91.0
# 3      92.0
# 4      93.0
# ...     ...
# 1467  520.0
# 1468  551.0
# 1469  535.0
# 1470  554.0
# 1471  596.0
#
# [1472 rows x 1 columns]

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/zyrex/Documents/programming/walletwise-stocks/wwvenv/lib/python3.12/site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/zyrex/Documents/programming/walletwise-stocks/wwvenv/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/zyrex/Documents/programming/walletwise-stocks/wwvenv/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/zyrex/Documents/programming/walletwise-stocks/wwvenv/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/zyrex/Documents/programming/walletwise-stocks/wwvenv/lib/python3.12/site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.preprocessing import MinMaxScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from sklearn.preprocessing import MinMaxScaler
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Check scikit-learn installation
# !pip show scikit-learn

# Import MinMaxScaler
#
# Out:
# Name: scikit-learn
# Version: 1.5.0
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /home/zyrex/Documents/programming/walletwise-stocks/wwvenv/lib/python3.12/site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by:

# %%
# !which python
# Out:
# /home/zyrex/Documents/programming/walletwise-stocks/wwvenv/bin/python

# %%
from sklearn.preprocessing import MinMaxScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from sklearn.preprocessing import MinMaxScaler
#
# ModuleNotFoundError: No module named 'sklearn'
